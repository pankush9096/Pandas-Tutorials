# %%
import pandas as pd

#codes: https://github.com/justmarkham/pandas-videos/blob/master/pandas.ipynb

# %%
#reading tabulate data .tsv separated by tab from a url so using read_table


#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_table.html
orders= pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#giving the separater and passing the column names manually
user_cols=['userid','age','gender','occupation','zipcode']
mu= pd.read_table('http://bit.ly/movieusers',sep='|',header=None, names=user_cols)

# %%
mu.head()
# Out:
#    userid  age gender  occupation zipcode
# 0       1   24      M  technician   85711
# 1       2   53      F       other   94043
# 2       3   23      M      writer   32067
# 3       4   24      M  technician   43537
# 4       5   33      F       other   15213

# %%
#diff btwn read table and read csv is read csv default delimeter is ','
ufo= pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#getting a column from a data frame , it will be series
ufo['City'].head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
ufo.City.head()
# Out:
# 0                  Ithaca
# 1             Willingboro
# 2                 Holyoke
# 3                 Abilene
# 4    New York Worlds Fair
# Name: City, dtype: object

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo['address']= ufo.City+','+ufo.State

# %%
ufo.address.head()
# Out:
# 0                  Ithaca,NY
# 1             Willingboro,NJ
# 2                 Holyoke,CO
# 3                 Abilene,KS
# 4    New York Worlds Fair,NY
# Name: address, dtype: object

# %%
movies= pd.read_csv("http://bit.ly/imdbratings")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe() # only gives statistical features of numeric columns
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
# in pandas methods or actions performed ends with parenthesis() and attributes or descriptive ends without it
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# Renaming the data frame columns
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    address
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo.rename(columns={'Colors Reported':'Reported_Color','Shape Reported':'Reported_Shape'}, inplace=True)

# %%
ufo.columns
# Out:
# Index(['City', 'Reported_Color', 'Reported_Shape', 'State', 'Time', 'address'], dtype='object')

# %%
ufo_cols=['City', 'Reported_Color', 'Reported_Shape', 'State', 'Time', 'Location']
ufo.columns= ufo_cols

# %%
ufo.columns
# Out:
# Index(['City', 'Reported_Color', 'Reported_Shape', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo= pd.read_csv("http://bit.ly/uforeports")

# %%
# so if want to just change the space with underscore in columns we can do
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.columns=ufo.columns.str.replace(' ','_')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
#droping the columns from a dataframe
ufo.drop(['City','State'],axis=1,inplace=True)

# %%
ufo.head()
# Out:
#   Colors_Reported Shape_Reported             Time
# 0             NaN       TRIANGLE   6/1/1930 22:00
# 1             NaN          OTHER  6/30/1930 20:00
# 2             NaN           OVAL  2/15/1931 14:00
# 3             NaN           DISK   6/1/1931 13:00
# 4             NaN          LIGHT  4/18/1933 19:00

# %%
# droping the rows
ufo.drop([0,1,99,1000],axis=0,inplace=True)
#axis 0 is default so if we dont pass it will take it by def

# %%
ufo.head()
# Out:
#   Colors_Reported Shape_Reported             Time
# 2             NaN           OVAL  2/15/1931 14:00
# 3             NaN           DISK   6/1/1931 13:00
# 4             NaN          LIGHT  4/18/1933 19:00
# 5             NaN           DISK  9/15/1934 15:30
# 6             NaN         CIRCLE   6/15/1935 0:00

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
#Sorting the values
# movies.title.sort_values()
# movies['title'].sort_values()#Ascending order
movies['title'].sort_values(ascending=False)#Descending order
type(movies['title'].sort_values())#will return series or sorting only a columns
# Out:
# pandas.core.series.Series

# %%
#Sorting the dataframe
movies.sort_values('duration',ascending=True,inplace=True)

# %%
movies.head()
# Out:
#      star_rating                        title content_rating    genre  \
# 389          8.0                       Freaks        UNRATED    Drama
# 338          8.0          Battleship Potemkin        UNRATED  History
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 88           8.4                      The Kid      NOT RATED   Comedy
#
#      duration                                        actors_list
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...

# %%
#Sorting on index
movies.sort_index(inplace=True)

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#sorting by two columns
movies.sort_values(['star_rating','duration'],inplace=True)
# so this will first sort on star rating and then on duration

# %%
movies.sort_index(inplace=True)

# %%
# filtering on columns
movies.shape
# Out:
# (979, 6)

# %%
#creating a list of boolean which will match the condition
boolean=[]
for l in movies['duration']:
    if l>=200:
        boolean.append(True)
    else:
        boolean.append(False)

# %%
islong=pd.Series(boolean)
movies[islong] # will return all the true values index data
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
#so easy way to this is
movies[movies['duration']>=200].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 17          8.7                                  Seven Samurai        UNRATED
# 78          8.4                    Once Upon a Time in America              R
# 85          8.4                             Lawrence of Arabia             PG
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78      Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85  Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...

# %%
#Filtering or slicing using multiple condition
movies[(movies['duration']>=200) & (movies['genre'] == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies[(movies['duration']>=200) | (movies['genre'] == 'Drama')].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 5           8.9                                   12 Angry Men      NOT RATED
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 9           8.9                                     Fight Club              R
# 13          8.8                                   Forrest Gump          PG-13
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 5       Drama        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 9       Drama       139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 13      Drama       142    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']

# %%
movies[(movies.genre.isin(['Crime','Drama']))].head()
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
# 4          8.9              Pulp Fiction              R  Crime       154
# 5          8.9              12 Angry Men      NOT RATED  Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
drinks=pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#How do I drop all non-numeric columns from a DataFrame?
drinks.dtypes
import numpy as np
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe(percentiles=[.1,.3,.73],include='all')
# Out:
#                    country  beer_servings  spirit_servings  wine_servings  \
# count                  193     193.000000       193.000000     193.000000
# unique                 193            NaN              NaN            NaN
# top     Bosnia-Herzegovina            NaN              NaN            NaN
# freq                     1            NaN              NaN            NaN
# mean                   NaN     106.160622        80.994819      49.450777
# std                    NaN     101.143103        88.284312      79.697598
# min                    NaN       0.000000         0.000000       0.000000
# 10%                    NaN       2.200000         0.000000       0.000000
# 30%                    NaN      25.000000        11.000000       2.000000
# 50%                    NaN      76.000000        56.000000       8.000000
# 73%                    NaN     169.320000       122.000000      54.320000
# max                    NaN     376.000000       438.000000     370.000000
#
# ...

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#how to use string method on pandas df or series
# https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html

orders['item_name'].str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
# 5                                CHICKEN BOWL
# 6                               SIDE OF CHIPS
# 7                               STEAK BURRITO
# 8                            STEAK SOFT TACOS
# 9                               STEAK BURRITO
# 10                        CHIPS AND GUACAMOLE
# 11                       CHICKEN CRISPY TACOS
# 12                         CHICKEN SOFT TACOS
# 13                               CHICKEN BOWL
# 14                        CHIPS AND GUACAMOLE
# 15      CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 16                            CHICKEN BURRITO
# 17                            CHICKEN BURRITO
# 18                                CANNED SODA
# 19                               CHICKEN BOWL
# ...

# %%
orders[orders['item_name'].str.contains('Chips')]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# 15           8         1  Chips and Tomatillo-Green Chili Salsa
# 20          10         1                    Chips and Guacamole
# 25          13         1           Chips and Fresh Tomato Salsa
# 30          15         1  Chips and Tomatillo-Green Chili Salsa
# 32          16         1                          Side of Chips
# 37          18         1                    Chips and Guacamole
# 38          18         1  Chips and Tomatillo Green Chili Salsa
# 40          19         1                                  Chips
# 41          20         1                    Chips and Guacamole
# ...

# %%
# Changing the data type
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks['beer_servings'].astype('float64')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price.str.replace("$","").astype(float).mean()
# Out:
# 7.464335785374397

# %%
orders.item_name.str.contains('Chips').astype(int).value_counts()
# Out:
# 0    3538
# 1    1084
# Name: item_name, dtype: int64

# %%
#Group by in pandas
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [raw]
# drinks.beer_servings.mean()

# %%
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.sum()
# Out:
# continent
# Africa           3258
# Asia             1630
# Europe           8720
# North America    3345
# Oceania          1435
# South America    2101
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent')['beer_servings'].agg(['mean','max','min','count','median'])
# Out:
#                      mean  max  min  count  median
# continent
# Africa          61.471698  376    0     53    32.0
# Asia            37.045455  247    0     44    17.5
# Europe         193.777778  361    0     45   219.0
# North America  145.434783  285    1     23   143.0
# Oceania         89.687500  306    0     16    52.5
# South America  175.083333  333   93     12   162.5

# %%
drinks.groupby('continent').sum()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa                3258.0              866            862
# Asia                  1630.0             2677            399
# Europe                8720.0             5965           6400
# North America         3345.0             3812            564
# Oceania               1435.0              935            570
# South America         2101.0             1377            749
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                159.4
# Asia                                   95.5
# Europe                                387.8
# North America                         137.9
# Oceania                                54.1
# South America                          75.7

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= [30,30])
drinks.groupby('continent').mean().plot(kind='Bar')

# %%
#Exploring the pandas series

movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
#Normalize arguement will get the percentage 
movies['genre'].value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
movies.genre.isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: genre, dtype: bool

# %%
movies.genre.isnull().any()
# Out:
# False

# %%
movies['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
#to get the cross tabulation for two columns 
pd.crosstab(movies.genre,movies.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
#numeric operation
movies.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
# %matplotlib inline

# %%
movies.duration.plot(kind='Hist')

# %%
movies.genre.value_counts().plot(kind='Bar')

# %%
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
#while suming the booleans it takes true as 1 and false as 0 and do the sum
pd.Series([True,False,True]).sum()
# Out:
# 2

# %%
#Droping the missing values using dropna

ufo.shape
ufo.isnull().nunique()
# Out:
# City               2
# Colors Reported    2
# Shape Reported     2
# State              1
# Time               1
# dtype: int64

# %%
#here its droping row if any of the columns has nan value, how=any is by default
ufo.dropna(how='any').shape
# Out:
# (2486, 5)

# %%
#it will drop the row if all the values of will be nan
ufo.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
#here it will check on passed columns and if any of them has nan value it will drop that row
ufo.dropna(subset=['City','Colors Reported'],how='any').shape
# Out:
# (2877, 5)

# %%
#here it will drop if both of the passed columns will have nana value
ufo.dropna(subset=['City','Colors Reported'],how='all').shape
# Out:
# (18221, 5)

# %%
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# HEXAGON         1
# PYRAMID         1
# FLARE           1
# DOME            1
# Name: Shape Reported, dtype: int64

# %%
#will replace nana with various
ufo['Shape Reported'].fillna('Various').value_counts()
# Out:
# LIGHT        2803
# Various      2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
#will replace nana with next value
ufo['Shape Reported'].fillna(method='ffill').value_counts()
# Out:
# LIGHT        3314
# DISK         2404
# TRIANGLE     2376
# OTHER        1635
# CIRCLE       1566
# SPHERE       1213
# FIREBALL     1199
# OVAL          965
# CIGAR         698
# FORMATION     503
# VARIOUS       369
# RECTANGLE     361
# CYLINDER      354
# CHEVRON       281
# DIAMOND       274
# EGG           229
# FLASH         209
# TEARDROP      141
# CONE           81
# CROSS          40
# DELTA          17
# ROUND           6
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
#will replace nan with previous value
ufo['Shape Reported'].fillna(method='bfill').value_counts()
# Out:
# LIGHT        3314
# DISK         2459
# TRIANGLE     2297
# OTHER        1622
# CIRCLE       1573
# SPHERE       1213
# FIREBALL     1154
# OVAL          971
# CIGAR         694
# FORMATION     523
# VARIOUS       388
# RECTANGLE     366
# CYLINDER      348
# CHEVRON       281
# DIAMOND       270
# EGG           227
# FLASH         223
# TEARDROP      149
# CONE           73
# CROSS          41
# DELTA          25
# ROUND          21
# DOME            4
# CRESCENT        2
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()

#here index is auto generated while importing the data, it wont be counted as sep column
drinks.shape
#it will give rows =193 and columns as 6 which are imported excluding the index
# Out:
# (193, 6)

# %%
# Indexing in the dataframe
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
#Here we are setting index as one of the imported columns where index name will be column name
drinks.set_index('country',inplace=True)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drinks.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
#setting back the normal index
# we are passsing index name as it will take that index and convert it to column
drinks.index.name='country'
drinks.reset_index(inplace=True)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#describe returns a dataframe which we can use
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
drinks.describe().columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
a=drinks.describe()

# %%
a.head()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
pop=pd.Series([200,300,400],index=[3,2,4])

# %%
#here it will multiply the values by matching the index
drinks.beer_servings * pop
# Out:
# 0          NaN
# 1          NaN
# 2       7500.0
# 3      49000.0
# 4      86800.0
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#         ...
# 163        NaN
# 164        NaN
# 165        NaN
# 166        NaN
# 167        NaN
# 168        NaN
# 169        NaN
# 170        NaN
# 171        NaN
# 172        NaN
# 173        NaN
# 174        NaN
# 175        NaN
# 176        NaN
# 177        NaN
# 178        NaN
# 179        NaN
# 180        NaN
# 181        NaN
# 182        NaN
# 183        NaN
# 184        NaN
# 185        NaN
# 186        NaN
# 187        NaN
# 188        NaN
# 189        NaN
# 190        NaN
# ...

# %%
#if we concat on columns then also it will match the index
pd.concat([drinks,pop], axis=1).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent      0
# 0                           0.0      Asia    NaN
# 1                           4.9    Europe    NaN
# 2                           0.7    Africa  300.0
# 3                          12.4    Europe  200.0
# 4                           5.9    Africa  400.0

# %%
# # Slicing through .iloc, .loc, .ix
# # .iloc= do slicing based on integer position or ranges 
# # .loc= do slicing based on labels
# # .ix= blend of .iloc and .loc # not recommended
# The loc method is used to select rows and columns by label. You can pass it:

# A single label
# A list of labels
# A slice of labels
# A boolean Series
# A colon (which indicates "all labels")

# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# row 0, all columns
ufo.loc[0, :]
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
# rows 0 and 1 and 2, all columns
ufo.loc[[0, 1, 2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# rows 0 through 2 (inclusive), all columns
ufo.loc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# this implies "all columns", but explicitly stating "all columns" is better
ufo.loc[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
# rows 0 through 2 (inclusive), column 'City'
ufo.loc[0:2, 'City']
# Out:
# 0         Ithaca
# 1    Willingboro
# 2        Holyoke
# Name: City, dtype: object

# %%
# rows 0 through 2 (inclusive), columns 'City' and 'State'
ufo.loc[0:2, ['City', 'State']]
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ
# 2      Holyoke    CO

# %%
# accomplish the same thing using double brackets - but using 'loc' is preferred since it's more explicit
ufo[['City', 'State']].head(3)
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ
# 2      Holyoke    CO

# %%
# rows 0 through 2 (inclusive), columns 'City' through 'State' (inclusive)
ufo.loc[0:2, 'City':'State']
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
# accomplish the same thing using 'head' and 'drop'
ufo.head(3).drop('Time', axis=1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
# rows in which the 'City' is 'Oakland', column 'State'
ufo.loc[ufo.City=='Oakland', 'State']
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %%
# accomplish the same thing using "chained indexing" - but using 'loc' is preferred since chained indexing can cause problems
ufo[ufo.City=='Oakland'].State
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %%
# The iloc method is used to select rows and columns by integer position. You can pass it:

# A single integer position
# A list of integer positions
# A slice of integer positions
# A colon (which indicates "all integer positions")
# rows in positions 0 and 1, columns in positions 0 and 3
ufo.iloc[[0, 1], [0, 3]]
# Out:
#           City State
# 0       Ithaca    NY
# 1  Willingboro    NJ

# %%
# rows in positions 0 through 2 (exclusive), columns in positions 0 through 4 (exclusive)
ufo.iloc[0:2, 0:4]
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ

# %%
# rows in positions 0 through 2 (exclusive), all columns
ufo.iloc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
# accomplish the same thing - but using 'iloc' is preferred since it's more explicit
ufo[0:2]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
# The ix method is used to select rows and columns by label or integer position,
# and should only be used when you need to mix label-based and integer-based selection in the same call.
# read a dataset of alcohol consumption into a DataFrame and set 'country' as the index
# Rules for using numbers with ix:

# If the index is strings, numbers are treated as integer positions, and thus slices are exclusive on the right.
# If the index is integers, numbers are treated as labels, and thus slices are inclusive.

drinks = pd.read_csv('http://bit.ly/drinksbycountry', index_col='country')
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
# row with label 'Albania', column in position 0
drinks.ix['Albania', 0]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# 89

# %%
# rows 'Albania' through 'Andorra' (inclusive), columns in positions 0 through 2 (exclusive)
drinks.ix['Albania':'Andorra', 0:2]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#          beer_servings  spirit_servings
# country
# Albania             89              132
# Algeria             25                0
# Andorra            245              138

# %%
# rows 0 through 2 (inclusive), columns in positions 0 through 2 (exclusive)
ufo.ix[0:2, 0:2]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#           City Colors Reported
# 0       Ithaca             NaN
# 1  Willingboro             NaN
# 2      Holyoke             NaN

# %%
drinks=pd.read_csv("http://bit.ly/drinksbycountry")

# %%
#Here we are checking memory usage of df
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks.info(memory_usage='Deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
#Deep true means its giving exact number of bytes each column is using
drinks.memory_usage(deep=True)
# Out:
# Index                              80
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                       12332
# dtype: int64

# %%
# This can be redued by changing categorical data to categories
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['continent']=drinks['continent'].astype('category').head()

# %%
drinks.dtypes
# Out:
# country                           object
# beer_servings                      int64
# spirit_servings                    int64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
drinks.continent.cat.codes.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# 4    0
# dtype: int8

# %%
drinks.memory_usage(deep=True)
#here bytes for continent has been decreased because now its stored as int category which has low memory usage then object
# Out:
# Index                              80
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                         744
# dtype: int64

# %%
# create a small DataFrame from a dictionary
df = pd.DataFrame({'ID':[100, 101, 102, 103], 'quality':['good', 'very good', 'good', 'excellent']})
df
# Out:
#     ID    quality
# 0  100       good
# 1  101  very good
# 2  102       good
# 3  103  excellent

# %%
# sort the DataFrame by the 'quality' Series (alphabetical order)
df.sort_values('quality')
# Out:
#     ID    quality
# 3  103  excellent
# 0  100       good
# 2  102       good
# 1  101  very good

# %%
# define a logical ordering for the categories
df['quality'] = df.quality.astype('category', categories=['good', 'very good', 'excellent'], ordered=True)
df.quality
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
# 0         good
# 1    very good
# 2         good
# 3    excellent
# Name: quality, dtype: category
# Categories (3, object): [good < very good < excellent]

# %%
# sort the DataFrame by the 'quality' Series (logical order)
df.sort_values('quality')
# Out:
#     ID    quality
# 0  100       good
# 2  102       good
# 1  101  very good
# 3  103  excellent

# %%
# comparison operators work with ordered categories
df.loc[df.quality > 'good', :]
# Out:
#     ID    quality
# 1  101  very good
# 3  103  excellent

# %%
#ramdom sampling
drinks.sample(n=3)
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 129         Palau            306               63             23
# 63         Gambia              8                0              1
# 40   Cook Islands              0              254             74
#
#      total_litres_of_pure_alcohol continent
# 129                           6.9   Oceania
# 63                            2.4    Africa
# 40                            5.9   Oceania

# %%
drinks.sample(n=5,random_state=0)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 111       Monaco              0                0              0
# 134  Philippines             71              186              1
# 44        Cyprus            192              154            113
# 123        Niger              3                2              1
# 158      Somalia              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 111                           0.0    Europe
# 134                           4.6      Asia
# 44                            8.2    Europe
# 123                           0.1    Africa
# 158                           0.0    Africa

# %%
#frac will taking fraction so 0.50 is 50%
drinks.sample(frac=0.50).head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 91          Kyrgyzstan             31               97              6
# 108          Mauritius             98               31             18
# 100         Madagascar             26               15              4
# 34                Chad             15                1              1
# 5    Antigua & Barbuda            102              128             45
#
#      total_litres_of_pure_alcohol      continent
# 91                            2.4           Asia
# 108                           2.6         Africa
# 100                           0.8         Africa
# 34                            0.4         Africa
# 5                             4.9  North America

# %%
#How to create dummy varible in pandas
#Dummy variable is encoding the categorical variable to int
titanic_train=pd.read_csv("http://bit.ly/kaggletrain")

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train['sec_male']=titanic_train.Sex.map({'male':1,'female':0})

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sec_male
# 0      0         A/5 21171   7.2500   NaN        S         1
# 1      0          PC 17599  71.2833   C85        C         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0
# 3      0            113803  53.1000  C123        S         0
# ...

# %%
pd.get_dummies(titanic_train.Sex).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
#so here it gave 2 col male and female with 1 as true and 0 as false 
#but when ever we use it we always take one less no of col than total col to avoid dummy variable trap so it will n-1

pd.get_dummies(titanic_train.Sex,prefix='Sex').iloc[:,1:].head()
# Out:
#    Sex_male
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
titanic_train.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
Embarked_dummies= pd.get_dummies(titanic_train.Embarked,prefix='Sex').iloc[:,1:]

# %%
titanic_train=pd.concat([titanic_train,Embarked_dummies],axis=1)

# %%
#getting dummies in Dataframe
titanic_train=pd.read_csv("http://bit.ly/kaggletrain")

# %%
pd.get_dummies(titanic_train,columns=['Sex','Embarked']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_female  Sex_male  Embarked_C  \
# 0         A/5 21171   7.2500   NaN           0         1           0
# 1          PC 17599  71.2833   C85           1         0           1
# 2  STON/O2. 3101282   7.9250   NaN           1         0           0
# ...

# %%
#now to remove one dummy variable as we always take one less we have parameter drop_first
pd.get_dummies(titanic_train,columns=['Sex','Embarked'],drop_first=True).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN         1           0           1
# 1          PC 17599  71.2833   C85         0           0           0
# 2  STON/O2. 3101282   7.9250   NaN         0           0           1
# ...

# %%
#How to work with Date and time in pandas
ufo=pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dtypes
#so we will see time is read as object
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
ufo.Time.str.slice(-5,-3).astype(int).head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int64

# %%
#changing to data time format
ufo['Time']=pd.to_datetime(ufo.Time)

# %%
ufo.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo.Time.dt.hour.head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int64

# %%
ufo.Time.dt.weekday_name.head()
# Out:
# 0     Sunday
# 1     Monday
# 2     Sunday
# 3     Monday
# 4    Tuesday
# Name: Time, dtype: object

# %%
ufo.Time.dt.weekday.head()
# Out:
# 0    6
# 1    0
# 2    6
# 3    0
# 4    1
# Name: Time, dtype: int64

# %%
ufo.Time.dt.time.head()
#many more are there search google
# Out:
# 0    22:00:00
# 1    20:00:00
# 2    14:00:00
# 3    13:00:00
# 4    19:00:00
# Name: Time, dtype: object

# %%
ufo.Time.dt.year.head()
# Out:
# 0    1930
# 1    1930
# 2    1931
# 3    1931
# 4    1933
# Name: Time, dtype: int64

# %%
ufo.Time.dt.month.head()
# Out:
# 0    6
# 1    6
# 2    2
# 3    6
# 4    4
# Name: Time, dtype: int64

# %%
ufo.Time.dt.day.head()
# Out:
# 0     1
# 1    30
# 2    15
# 3     1
# 4    18
# Name: Time, dtype: int64

# %%
import time
ts=pd.to_datetime(time.time())

# %%
ts
# Out:
# Timestamp('1970-01-01 00:00:01.562306709')

# %%
ufo.Time.max()-ufo.Time.min()
# Out:
# Timedelta('25781 days 01:59:00')

# %%
(ufo.Time.max()-ufo.Time.min()).days
# Out:
# 25781

# %%
# How to find and remove duplicates in pandas
#giving the separater and passing the column names manually
user_cols=['userid','age','gender','occupation','zipcode']
mu= pd.read_table('http://bit.ly/movieusers',sep='|',header=None, names=user_cols, index_col='userid')

# %%
mu.shape
# Out:
# (943, 4)

# %%
mu.head()
# Out:
#         age gender  occupation zipcode
# userid
# 1        24      M  technician   85711
# 2        53      F       other   94043
# 3        23      M      writer   32067
# 4        24      M  technician   43537
# 5        33      F       other   15213

# %%
#This returns false for new value and true if its already appeared up in zipcode columns
mu.zipcode.duplicated().
# Out:
# False    795
# True     148
# Name: zipcode, dtype: int64

# %%
#this will do it for full row in df
mu.duplicated().sum()
# Out:
# 7

# %%
mu.duplicated().value_counts()
# Out:
# False    936
# True       7
# dtype: int64

# %%
#now we want to extract that 7 duplicated value
mu.loc[mu.duplicated(),:]
# Out:
#         age gender occupation zipcode
# userid
# 496      21      F    student   55414
# 572      51      M   educator   20003
# 621      17      M    student   60402
# 684      28      M    student   55414
# 733      44      F      other   60630
# 805      27      F      other   20009
# 890      32      M    student   97301

# %%
#return the first occurence
mu.loc[mu.duplicated(keep='first'),:]
# Out:
#         age gender occupation zipcode
# userid
# 496      21      F    student   55414
# 572      51      M   educator   20003
# 621      17      M    student   60402
# 684      28      M    student   55414
# 733      44      F      other   60630
# 805      27      F      other   20009
# 890      32      M    student   97301

# %%
#return the last occurence
mu.loc[mu.duplicated(keep='last'),:]
# Out:
#         age gender occupation zipcode
# userid
# 67       17      M    student   60402
# 85       51      M   educator   20003
# 198      21      F    student   55414
# 350      32      M    student   97301
# 428      28      M    student   55414
# 437      27      F      other   20009
# 460      44      F      other   60630

# %%
#return all occurence for dups
mu.loc[mu.duplicated(keep=False),:]
# Out:
#         age gender occupation zipcode
# userid
# 67       17      M    student   60402
# 85       51      M   educator   20003
# 198      21      F    student   55414
# 350      32      M    student   97301
# 428      28      M    student   55414
# 437      27      F      other   20009
# 460      44      F      other   60630
# 496      21      F    student   55414
# 572      51      M   educator   20003
# 621      17      M    student   60402
# 684      28      M    student   55414
# 733      44      F      other   60630
# 805      27      F      other   20009
# 890      32      M    student   97301

# %%
#dropping the full row 
mu.drop_duplicates()
# Out:
#         age gender     occupation zipcode
# userid
# 1        24      M     technician   85711
# 2        53      F          other   94043
# 3        23      M         writer   32067
# 4        24      M     technician   43537
# 5        33      F          other   15213
# 6        42      M      executive   98101
# 7        57      M  administrator   91344
# 8        36      M  administrator   05201
# 9        29      M        student   01002
# 10       53      M         lawyer   90703
# 11       39      F          other   30329
# 12       28      F          other   06405
# 13       47      M       educator   29206
# 14       45      M      scientist   55106
# 15       49      F       educator   97301
# 16       21      M  entertainment   10309
# 17       30      M     programmer   06355
# 18       35      F          other   37212
# 19       40      M      librarian   02138
# 20       42      F      homemaker   95660
# 21       26      M         writer   30068
# ...

# %%
mu.drop_duplicates(subset=['age','zipcode'],keep='first')
# Out:
#         age gender     occupation zipcode
# userid
# 1        24      M     technician   85711
# 2        53      F          other   94043
# 3        23      M         writer   32067
# 4        24      M     technician   43537
# 5        33      F          other   15213
# 6        42      M      executive   98101
# 7        57      M  administrator   91344
# 8        36      M  administrator   05201
# 9        29      M        student   01002
# 10       53      M         lawyer   90703
# 11       39      F          other   30329
# 12       28      F          other   06405
# 13       47      M       educator   29206
# 14       45      M      scientist   55106
# 15       49      F       educator   97301
# 16       21      M  entertainment   10309
# 17       30      M     programmer   06355
# 18       35      F          other   37212
# 19       40      M      librarian   02138
# 20       42      F      homemaker   95660
# 21       26      M         writer   30068
# ...

# %%
mu.drop_duplicates(subset=['age','zipcode'],keep='last')
# Out:
#         age gender     occupation zipcode
# userid
# 1        24      M     technician   85711
# 2        53      F          other   94043
# 3        23      M         writer   32067
# 4        24      M     technician   43537
# 5        33      F          other   15213
# 6        42      M      executive   98101
# 7        57      M  administrator   91344
# 8        36      M  administrator   05201
# 9        29      M        student   01002
# 10       53      M         lawyer   90703
# 11       39      F          other   30329
# 12       28      F          other   06405
# 13       47      M       educator   29206
# 14       45      M      scientist   55106
# 15       49      F       educator   97301
# 16       21      M  entertainment   10309
# 17       30      M     programmer   06355
# 18       35      F          other   37212
# 19       40      M      librarian   02138
# 20       42      F      homemaker   95660
# 21       26      M         writer   30068
# ...

# %%
#how to change display options
# pd.get_option=http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_option.html
# pd.set_option=http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html
# pd.reset_option=http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.reset_option.html
# pd.decribe_option=http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.describe_option.html

# %%
drinks=pd.read_csv('http://bit.ly/drinksbycountry')

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.set_option('display.max_rows',100)# now it will set the max_row showed to 100

# %%
drinks
# Out:
#                           country  beer_servings  spirit_servings  \
# 0                     Afghanistan              0                0
# 1                         Albania             89              132
# 2                         Algeria             25                0
# 3                         Andorra            245              138
# 4                          Angola            217               57
# 5               Antigua & Barbuda            102              128
# 6                       Argentina            193               25
# 7                         Armenia             21              179
# 8                       Australia            261               72
# 9                         Austria            279               75
# 10                     Azerbaijan             21               46
# 11                        Bahamas            122              176
# 12                        Bahrain             42               63
# ...

# %%
pd.set_option('display.max_rows',None)# this will display all rows

# %%
drinks
# Out:
#                           country  beer_servings  spirit_servings  \
# 0                     Afghanistan              0                0
# 1                         Albania             89              132
# 2                         Algeria             25                0
# 3                         Andorra            245              138
# 4                          Angola            217               57
# 5               Antigua & Barbuda            102              128
# 6                       Argentina            193               25
# 7                         Armenia             21              179
# 8                       Australia            261               72
# 9                         Austria            279               75
# 10                     Azerbaijan             21               46
# 11                        Bahamas            122              176
# 12                        Bahrain             42               63
# ...

# %%
pd.reset_option('display.max_rows')

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
# read the training dataset from Kaggle's Titanic competition into a DataFrame
train = pd.read_csv('http://bit.ly/kaggletrain')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# an ellipsis is displayed in the 'Name' cell of row 1 because of the 'max_colwidth' option
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
# overwrite the current setting so that more characters will be displayed
pd.set_option('display.max_colwidth', 1000)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
pd.reset_option('display.max_colwidth')

# %%
# overwrite the 'precision' setting to display 2 digits after the decimal point of 'Fare'
pd.set_option('display.precision', 2)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171   7.25   NaN        S
# 1      0          PC 17599  71.28   C85        C
# 2      0  STON/O2. 3101282   7.92   NaN        S
# 3      0            113803  53.10  C123        S
# 4      0            373450   8.05   NaN        S

# %%
# add two meaningless columns to the drinks DataFrame
drinks['x'] = drinks.wine_servings * 1000
drinks['y'] = drinks.total_litres_of_pure_alcohol * 1000
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent       x        y
# 0                           0.0      Asia       0      0.0
# 1                           4.9    Europe   54000   4900.0
# 2                           0.7    Africa   14000    700.0
# 3                          12.4    Europe  312000  12400.0
# 4                           5.9    Africa   45000   5900.0

# %%
# use a Python format string to specify a comma as the thousands separator
pd.set_option('display.float_format', '{:,}'.format)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent       x        y
# 0                           0.0      Asia       0      0.0
# 1                           4.9    Europe   54000  4,900.0
# 2                           0.7    Africa   14000    700.0
# 3                          12.4    Europe  312000 12,400.0
# 4                           5.9    Africa   45000  5,900.0

# %%
# 'y' was affected (but not 'x') because the 'float_format' option only affects floats (not ints)
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# x                                 int64
# y                               float64
# dtype: object

# %%
# view the option descriptions (including the default and current values)
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
#
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
#
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
#
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
#
# display.column_space No description available.
#     [default: 12] [currently: 12]
#
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
# ...

# %%
# search for specific options by name
pd.describe_option('rows')
# Out:
# display.max_info_rows : int or None
#     df.info() will usually show null-counts for each column.
#     For large frames this can be quite slow. max_info_rows and max_info_cols
#     limit this null check only to frames with smaller dimensions than
#     specified.
#     [default: 1690785] [currently: 1690785]
#
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]

# %%
# reset all of the options to their default values
pd.reset_option('all')
# Out:
# html.border has been deprecated, use display.html.border instead
# (currently both are identical)
#
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# /anaconda3/lib/python3.7/site-packages/pandas/core/config.py:619: FutureWarning: html.border has been deprecated, use display.html.border instead
# (currently both are identical)
#
#   warnings.warn(d.msg, FutureWarning)
# /anaconda3/lib/python3.7/site-packages/pandas/core/config.py:619: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
#How do I create a pandas DataFrame from another object
# create a DataFrame from a dictionary (keys become column names, values become data)
pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']})
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
# optionally specify the order of columns and define the index
df = pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']}, columns=['id', 'color'], index=['a', 'b', 'c'])
df
# Out:
#     id color
# a  100   red
# b  101  blue
# c  102   red

# %%
# create a DataFrame from a list of lists (each inner list becomes a row)
pd.DataFrame([[100, 'red'], [101, 'blue'], [102, 'red']], columns=['id', 'color'])
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
# create a NumPy array (with shape 4 by 2) and fill it with random numbers between 0 and 1
import numpy as np
arr = np.random.rand(4, 2)
arr
# Out:
# array([[0.44517301, 0.08703231],
#        [0.91183568, 0.09869931],
#        [0.00826487, 0.19124287],
#        [0.07481918, 0.61094131]])

# %%
pd.DataFrame(arr,columns=[1,2])
# Out:
#           1         2
# 0  0.445173  0.087032
# 1  0.911836  0.098699
# 2  0.008265  0.191243
# 3  0.074819  0.610941

# %%
# create a DataFrame of student IDs (100 through 109) and test scores (random integers between 60 and 100)
pd.DataFrame({'student':np.arange(100, 110, 1), 'test':np.random.randint(60, 101, 10)})
# Out:
#    student  test
# 0      100    63
# 1      101    88
# 2      102    94
# 3      103    74
# 4      104    84
# 5      105    80
# 6      106    87
# 7      107    96
# 8      108    67
# 9      109    97

# %%
# 'set_index' can be chained with the DataFrame constructor to select an index
pd.DataFrame({'student':np.arange(100, 110, 1), 'test':np.random.randint(60, 101, 10)}).set_index('student')
# Out:
#          test
# student
# 100        62
# 101        72
# 102        62
# 103        64
# 104        97
# 105        78
# 106        98
# 107        63
# 108        77
# 109        73

# %%
# create a new Series using the Series constructor
s = pd.Series(['round', 'square'], index=['c', 'b'], name='shape')
s
# Out:
# c     round
# b    square
# Name: shape, dtype: object

# %%
# concatenate the DataFrame and the Series (use axis=1 to concatenate columns)


# The Series name became the column name in the DataFrame.
# The Series data was aligned to the DataFrame by its index.
# The 'shape' for row 'a' was marked as a missing value (NaN) because that index was not present in the Series.
pd.concat([df, s], axis=1)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#     id color   shape
# a  100   red     NaN
# b  101  blue  square
# c  102   red   round

# %%
#How to use apply function to apply function


# read the training dataset from Kaggle's Titanic competition into a DataFrame
train = pd.read_csv('http://bit.ly/kaggletrain')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.0      1
# 2                             Heikkinen, Miss. Laina  female 26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.0      1
# 4                           Allen, Mr. William Henry    male 35.0      0
#
#    Parch            Ticket    Fare Cabin Embarked
# 0      0         A/5 21171    7.25   NaN        S
# 1      0          PC 17599 71.2833   C85        C
# 2      0  STON/O2. 3101282   7.925   NaN        S
# 3      0            113803    53.1  C123        S
# 4      0            373450    8.05   NaN        S

# %%
# map 'female' to 0 and 'male' to 1
train['Sex_num'] = train.Sex.map({'female':0, 'male':1})
train.loc[0:4, ['Sex', 'Sex_num']]
# Out:
#       Sex  Sex_num
# 0    male        1
# 1  female        0
# 2  female        0
# 3  female        0
# 4    male        1

# %%
# calculate the length of each string in the 'Name' Series and 4th row included
train['Name_length'] = train.Name.apply(len)
train.loc[0:4, ['Name', 'Name_length']]
# Out:
#                                                 Name  Name_length
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                             Heikkinen, Miss. Laina           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                           Allen, Mr. William Henry           24

# %%
# round up each element in the 'Fare' Series to the next integer
import numpy as np
train['Fare_ceil'] = train.Fare.apply(np.ceil)
train.loc[0:4, ['Fare', 'Fare_ceil']]
# Out:
#      Fare  Fare_ceil
# 0    7.25        8.0
# 1 71.2833       72.0
# 2   7.925        8.0
# 3    53.1       54.0
# 4    8.05        9.0

# %%
# we want to extract the last name of each person
train.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# use a string method to split the 'Name' Series at commas (returns a Series of lists)
train.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
# define a function that returns an element from a list based on position
def get_element(my_list, position):
    return my_list[position]

# %%
# apply the 'get_element' function and pass 'position' as a keyword argument
train.Name.str.split(',').apply(get_element, position=0).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
# alternatively, use a lambda function
train.Name.str.split(',').apply(lambda x: x[0]).head()
# Out:
# 0       Braund
# 1      Cumings
# 2    Heikkinen
# 3     Futrelle
# 4        Allen
# Name: Name, dtype: object

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# select a subset of the DataFrame to work with
drinks.loc[:, 'beer_servings':'wine_servings'].head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45

# %%
# apply the 'max' function along axis 0 to calculate the maximum value in each column
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
# apply the 'max' function along axis 1 to calculate the maximum value in each row
drinks.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=1).head()
# Out:
# 0      0
# 1    132
# 2     25
# 3    312
# 4    217
# dtype: int64

# %%
# use 'np.argmax' to calculate which column has the maximum value for each row
drinks.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis=1).head()
# Out:
# 0      beer_servings
# 1    spirit_servings
# 2      beer_servings
# 3      wine_servings
# 4      beer_servings
# dtype: object

# %%
#Applymap:

# convert every DataFrame element into a float
drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float).head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          245.0            138.0          312.0
# 4          217.0             57.0           45.0

# %%
# overwrite the existing DataFrame columns
drinks.loc[:, 'beer_servings':'wine_servings'] = drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0              0.0            0.0
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              0.0           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#multilevel indexing in python. Multiindex adds another dimension to data.
import pandas as pd
stocks= pd.read_csv("http://bit.ly/smallstocks")

# %%
stocks.head()
# Out:
#          Date  Close    Volume Symbol
# 0  2016-10-03   31.5  14070500   CSCO
# 1  2016-10-03 112.52  21701800   AAPL
# 2  2016-10-03  57.42  19189500   MSFT
# 3  2016-10-04  113.0  29736800   AAPL
# 4  2016-10-04  57.24  20085900   MSFT

# %%
stocks.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
stocks.groupby('Symbol').Close.mean()
# Out:
# Symbol
# AAPL    112.856667
# CSCO     31.480000
# MSFT     57.433333
# Name: Close, dtype: float64

# %%
series=stocks.groupby(['Symbol','Date']).Close.mean()

# %%
series
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
series.index
# Out:
# MultiIndex(levels=[['AAPL', 'CSCO', 'MSFT'], ['2016-10-03', '2016-10-04', '2016-10-05']],
#            labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]],
#            names=['Symbol', 'Date'])

# %%
series.unstack()
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
df=stocks.pivot_table(values='Close',index="Symbol",columns='Date')

# %%
stocks.pivot(values='Close',index="Symbol",columns='Date')
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52       113.0      113.05
# CSCO          31.5       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
df
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
series
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
series.loc['AAPL']
# Out:
# Date
# 2016-10-03    112.52
# 2016-10-04    113.00
# 2016-10-05    113.05
# Name: Close, dtype: float64

# %%
series.loc['AAPL','2016-10-03']
# Out:
# 112.52

# %%
series.loc[:,'2016-10-03']
# Out:
# Symbol
# AAPL    112.52
# CSCO     31.50
# MSFT     57.42
# Name: Close, dtype: float64

# %%
df.loc['AAPL','2016-10-03']
# Out:
# 112.52

# %%
df.loc[:,'2016-10-03']
# Out:
# Symbol
# AAPL    112.52
# CSCO     31.50
# MSFT     57.42
# Name: 2016-10-03, dtype: float64

# %%
stocks
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL

# %%
stocks.set_index(['Symbol','Date'], inplace=True)

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# CSCO   2016-10-03   31.50  14070500
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500
# AAPL   2016-10-04  113.00  29736800
# MSFT   2016-10-04   57.24  20085900
# CSCO   2016-10-04   31.35  18460400
# MSFT   2016-10-05   57.64  16726400
# CSCO   2016-10-05   31.59  11808600
# AAPL   2016-10-05  113.05  21453100

# %%
stocks.sort_index(inplace=True)

# %%
stocks
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
#        2016-10-05   31.59  11808600
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
stocks.loc['AAPL']
# Out:
#              Close    Volume
# Date
# 2016-10-03  112.52  21701800
# 2016-10-04  113.00  29736800
# 2016-10-05  113.05  21453100

# %%
#But when we want to pass miltiindex we will pass it as tuple
stocks.loc[[('AAPL','2016-10-03'),('MSFT','2016-10-04')],:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-04   57.24  20085900

# %%
stocks.loc[(['AAPL','MSFT'],'2016-10-03'),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500

# %%
#here in multiindex : wont work so we will use Slice(None)
stocks.loc[(['AAPL','MSFT'],:),:]
# Out:
#   File "<ipython-input-28-b44bb0823f08>", line 1
#     stocks.loc[(['AAPL','MSFT'],:),:]
#                                 ^
# SyntaxError: invalid syntax

# %%
stocks.loc[(['AAPL','MSFT'],slice(None)),:]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400
